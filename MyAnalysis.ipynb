# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

# %%
a= pd.read_csv("./SalesAnalysis/Sales_Data/Sales_April_2019.csv")

# %%
YearFiles = [files for files in listdir("./SalesAnalysis/Sales_Data") ]

# %%
## READING THE DATA##

# %%
a.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
for files in YearFiles:
    allmonthdata=pd.DataFrame()
    df=pd.read_csv("./SalesAnalysis/Sales_Data/"+files)
    allmonthdata=pd.concat([allmonthdata,df])

# %%
allmonthdata.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %%
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %%
allmonthdata.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count      11646                 11646            11646      11646
# unique     11208                    20                7         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq          17                  1454            10490       1454
#
#         Order Date  Purchase Address
# count        11646             11646
# unique        9495             11032
# top     Order Date  Purchase Address
# freq            17                17

# %%
allmonthdata.to_csv("./allmonthdata.csv", index=False)

# %%
data=pd.read_csv("./allmonthdata.csv")

# %%
data.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %% [markdown]
# ## WHAT WAS THE BEST MONTH FOR SALES AND HOW MUCH WAS EARNED##

# %%
##CLEANING THE DATA
nullvalues_month=data.isnull().sum().sum()
nullvalues_month
# Out:
# 240

# %%
CleanData=data.dropna(how="any")
CleanData.head(200)
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 0     248151       AA Batteries (4-pack)                4       3.84
# 1     248152        USB-C Charging Cable                2      11.95
# 2     248153        USB-C Charging Cable                1      11.95
# 3     248154            27in FHD Monitor                1     149.99
# 4     248155        USB-C Charging Cable                1      11.95
# ..       ...                         ...              ...        ...
# 195   248338        USB-C Charging Cable                1      11.95
# 196   248339  Bose SoundSport Headphones                1      99.99
# 197   248340      AAA Batteries (4-pack)                1       2.99
# 199   248341        USB-C Charging Cable                1      11.95
# 200   248342    Apple Airpods Headphones                1        150
#
#          Order Date                       Purchase Address
# 0    09/17/19 14:44    380 North St, Los Angeles, CA 90001
# 1    09/29/19 10:19           511 8th St, Austin, TX 73301
# 2    09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001
# 3    09/27/19 07:52      355 Hickory St, Seattle, WA 98101
# 4    09/01/19 19:03          125 5th St, Atlanta, GA 30301
# ..              ...                                    ...
# 195  09/16/19 10:48          811 12th St, Boston, MA 02215
# 196  09/08/19 21:04  723 North St, San Francisco, CA 94016
# 197  09/13/19 20:08         896 12th St, Seattle, WA 98101
# 199  09/18/19 11:39      755 5th St, Los Angeles, CA 90001
# 200  09/11/19 00:43    922 Elm St, New York City, NY 10001
#
# [200 rows x 6 columns]

# %%
CleanData["Months"]=CleanData["Order Date"].str[0:2]

CleanData.head()
# Out:
# <ipython-input-109-f0fb79348741>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanData["Months"]=CleanData["Order Date"].str[0:2]
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address Months
# 0    380 North St, Los Angeles, CA 90001     09
# 1           511 8th St, Austin, TX 73301     09
# 2  151 Johnson St, Los Angeles, CA 90001     09
# 3      355 Hickory St, Seattle, WA 98101     09
# 4          125 5th St, Atlanta, GA 30301     09

# %%
CleanData=CleanData[CleanData["Order Date"].str[:2]!="or" ]
CleanData.head()
CleanData.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count      11646                 11646            11646      11646
# unique     11208                    20                7         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq          17                  1454            10490       1454
#
#         Order Date  Purchase Address Months
# count        11646             11646  11646
# unique        9495             11032      3
# top     Order Date  Purchase Address     09
# freq            17                17  11609

# %%
CleanData["Quantity Ordered"]=pd.to_numericsCleanData["Quantity Ordered"]
CleanData["Price Each"]

# %%
CleanData["Sales"] = CleanData["Quantity Ordered"]*CleanData["Price Each"]
CleanData.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#
# TypeError: can't multiply sequence by non-int of type 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-d8955eb35c01> in <module>
# ----> 1 CleanData["Sales"] = CleanData["Quantity Ordered"]*CleanData["Price Each"]
#       2 CleanData.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __mul__(self, other)
#     103     @unpack_zerodim_and_defer("__mul__")
#     104     def __mul__(self, other):
# --> 105         return self._arith_method(other, operator.mul)
#     106
#     107     @unpack_zerodim_and_defer("__rmul__")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    4996         lvalues = extract_array(self, extract_numpy=True)
#    4997         rvalues = extract_array(other, extract_numpy=True)
# -> 4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
#    5000         return self._construct_result(result, name=res_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     147             #  will handle complex numbers incorrectly, see GH#32047
#     148             raise
# --> 149         result = _masked_arith_op(left, right, op)
#     150
#     151     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#      89         if mask.any():
#      90             with np.errstate(all="ignore"):
# ---> 91                 result[mask] = op(xrav[mask], yrav[mask])
#      92
#      93     else:
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
best_sales_month=data.sum("Price Each").groupby("Months")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 'Price Each'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-5482e855c2de> in <module>
# ----> 1 best_sales_month=data.sum("Price Each").groupby("Months")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11069             **kwargs,
#   11070         ):
# > 11071             return NDFrame.sum(
#   11072                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11073             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10789         **kwargs,
#   10790     ):
# > 10791         return self._min_count_stat_function(
#   10792             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10793         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10771                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   10772             )
# > 10773         return self._reduce(
#   10774             func,
#   10775             name=name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    8809
#    8810         # TODO: Make other agg func handle axis=None properly GH#21597
# -> 8811         axis = self._get_axis_number(axis)
#    8812         labels = self._get_agg_axis(axis)
#    8813         assert axis in [0, 1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
# --> 462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     463
#     464     @final
#
# ValueError: No axis named Price Each for object type DataFrame
